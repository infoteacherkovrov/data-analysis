# %% [markdown]
# <a href="https://colab.research.google.com/github/infoteacherkovrov/data-analysis/blob/main/Yandex_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Для сохранения изменений выберете <b>Файл -> Сохранить копию в GitHub</b>

# %% [markdown]
# [Ссылка на вариант (Январь 2026 уровень средний Яндекс Андрей Рогов) ](https://education.yandex.ru/ege/inf/variants/a7c29644-cc86-4f29-803b-94fffb1d7c05/task/1)

# %% [markdown]
# #Задание 2

# %%
#вставьте сюда код задание 2

# %% [markdown]
# #Задание 5

# %%
#вставьте сюда код задания 5
