# %% [markdown]
# [Ссылка на вариант](https://education.yandex.ru/ege/inf/variants/a7c29644-cc86-4f29-803b-94fffb1d7c05/task/1)

# %% [markdown]
# #Задание 2

# %%
#cюда текст программы

# %% [markdown]
# #Задание 5

# %%
#сюда текст программы

# %% [markdown]
# #Задание 14

# %%
alph = "0123456789QWERTYUIOPASDFGHJKLZXCVBNM"
alph = sorted(alph)
alph = alph[:21][::-1]
for x in alph:
    if (int("EF"+x+"67",21)+int("3H"+x+"4C",21)) % 20 == 0:
        print((int("EF"+x+"67",21)+int("3H"+x+"4C",21))//7)
        break
# Out:
# 516065

# %% [markdown]
# # Задание 25

# %%
# Out:
# 2142622
# 2142626
# 2142674
# 2142682
# 2142698
# --
# 1071311
# 1071313
# 1071337
# 1071341
# 1071349

# %%
# Out:
# 2142622 1071311
# 2142626 1071313
# 2142674 1071337
# 2142682 1071341
# 2142698 1071349
